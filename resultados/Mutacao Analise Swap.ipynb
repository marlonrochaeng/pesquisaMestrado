# %%
import pandas as pd

# %%
df_ag = pd.read_csv('../resultados/mesma populacao/mutacao swap/ag_mutacao_swap.csv',index_col=0)
df_ag.style.format("{:.2f}")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10945/3211527365.py in <module>
# ----> 1 df_ag = pd.read_csv('../resultados/mesma populacao/mutacao swap/ag_mutacao_swap.csv',index_col=0)
#       2 df_ag.style.format("{:.2f}")
#       3 pd.set_option('display.float_format', lambda x: '%.3f' % x)
#
# ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_ag.loc[df_ag['makespan'].isin(df_ag.groupby('instance')['makespan'].min().values)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10945/2004859859.py in <module>
# ----> 1 df_ag.loc[df_ag['makespan'].isin(df_ag.groupby('instance')['makespan'].min().values)]
#
# NameError: name 'df_ag' is not defined

# %%
df_eda = pd.read_csv('../resultados/mesma populacao/mutacao swap/eda_mutacao_swap.csv',index_col=0)
df_eda.style.format("{:.2f}")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df_eda.loc[df_eda['makespan'].isin(df_eda.groupby('instance')['makespan'].min().values)]

# %%
df_eda.loc[df_eda['makespan'].isin(df_eda.groupby('instance')['makespan'].min().values)]
# Out:
#     jobs  machines  numInd  numGen    makespan  to_matrix_percentage  \
# 4    512        16     100     100   99563.054                 0.300
# 6    512        16     100     100 4621486.670                 0.300
# 12   512        16     100     100  132641.710                 0.300
# 14   512        16     100     100    3585.936                 0.300
# 17   512        16     100     100   75207.257                 0.300
# 22   512        16     100     100 3068641.279                 0.300
# 25   512        16     100     100  110568.715                 0.300
# 32   512        16     100     100    2609.982                 0.300
# 33   512        16     100     100  160807.828                 0.300
# 39   512        16     100     100 8142691.785                 0.300
# 42   512        16     100     100  271166.439                 0.300
# 45   512        16     100     100    5409.638                 0.300
#
#     elitismo  exec_time    instance  mutation selection_method
# ...

# %%
df_ag_swap = pd.read_csv('../resultados/mesma populacao/mutacao swap/ag_mutacao_swap.csv',index_col=0)
df_ag_swap.style.format("{:.2f}")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
df1 = df_ag_swap.loc[df_ag_swap['makespan'].isin(df_ag_swap.groupby('instance')['makespan'].min().values)]

# %%
count_swap = 0
count_simp = 0
for i in range(len(df_ag_swap)):
    if df_ag_swap.loc[i]['makespan'] > df_ag.loc[i]['makespan']:
        count_swap += 1
    else:
        count_simp += 1

# %%
count_simp, count_swap
# Out:
# (48, 0)
